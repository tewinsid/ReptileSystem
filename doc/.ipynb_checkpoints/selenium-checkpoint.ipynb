# %%
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC

browser = webdriver.Chrome()
try:
    browser.get('https://book.douban.com/')
#     找到输入项
    input = browser.find_element_by_id('inp-query')
#     输入Ｐｙｔｈｏｎ
    input.send_keys('Python')
#     输入回车
    input.send_keys(Keys.ENTER)
    wait = WebDriverWait(browser, 10)
#     等待地为content_left的元素完成加载
    wait.until(EC.presence_of_element_located((By.ID,"search_suggest")))
    print(browser.current_url)
    print(browser.get_cookies())
    print(browser.page_source)
finally:
    browser.close()
# Out:
# https://book.douban.com/subject_search?search_text=Python&cat=1001
# ...

# %% [markdown]
# # 声明浏览器对象

# %%
from selenium import webdriver
# 要有对应的驱动
browser = webdriver.Chrome()
# browser = webdriver# 访问界面.Firefox()

# %% [markdown]
# # 查找元素

# %%
from selenium import webdriver

browser = webdriver.Chrome()
browser.get('https://www.taobao.com/')
input_first = browser.find_element_by_id('q')
input_second = browser.find_element_by_css_selector('#q')
input_third = browser.find_element_by_xpath('//*[@id="q"]')
print(input_first, input_second, input_third)
browser.close()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="671a6b4e1b0b7ffdf3c198ac9198a22f", element="0.42473785862392255-1")> <selenium.webdriver.remote.webelement.WebElement (session="671a6b4e1b0b7ffdf3c198ac9198a22f", element="0.42473785862392255-1")> <selenium.webdriver.remote.webelement.WebElement (session="671a6b4e1b0b7ffdf3c198ac9198a22f", element="0.42473785862392255-1")>

# %% [markdown]
# find_element_by_name
# find_element_by_xpath
# find_element_by_link_text
# find_element_by_partial_link_text
# find_element_by_tag_name
# find_element_by_class_name
# find_element_by_css_selector

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

browser = webdriver.Chrome()
browser.get('https://www.taobao.com/')
# 通用版本，用Ｂｙ
input = browser.find_element(By.ID, 'q')
print(input)
browser.close()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ec3667b63c810c2c95b6dd9c9b00e1d0", element="0.9715141940529182-1")>

# %% [raw]
# 多个元素

# %% [raw]
# input_second = browser.find_elements_by_css_selector('#q')
# input = browser.find_elements(By.ID, 'q')

# %% [markdown]
# 执行javaScri

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

browser = webdriver.Chrome()
browser.get('https://www.taobao.com/')
browser.execute_seript("alert('todo')")
